# %%
# Install all python requirements and dependencies for running Pheflux if you have not already done so
pip install -r requirements.txt

# %%
import sys
import re
# Add Pheflux directory to path
sys.path.append("C:/Users/arm037/OneDrive - Thomas Jefferson University/GEM_Modeling_Dec2020/PatientGEMPaper/Pheflux")
import pheflux
# Out:
# Welcome to PheFlux !

# %%
inputFile       = "PhefluxInputData_Example.csv" # input csv directory

# %%
resultsDir      = "" # results directory

# %%
verbosity       = True # Verbose mode

# %%
prefix_log_file = "Test"  # Prefix log output file.

# %%
pheflux.getFluxes(inputFile,resultsDir,prefix_log_file,verbosity) # Run PheFlux
